# %%
import pandas as pd
import numpy as np
import os

# %%
RAW_PATH = '../data/raw_sales_data.csv'
df = pd.read_csv(RAW_PATH)
print(f"✅ Raw dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# ✅ Raw dataset loaded: 5000 rows, 10 columns

# %%
# -------------------- Data Cleaning --------------------
# 1. Drop duplicates
df.drop_duplicates(inplace=True)

# 2. Handle missing values
df.fillna({
    'Discount': 0,
    'Profit': df['Profit'].mean() if 'Profit' in df.columns else 0
}, inplace=True)

# 3. Convert 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# 4. Remove any invalid or future dates
df = df[df['Date'] <= pd.Timestamp.today()]

# 5. Add derived columns
df['Revenue'] = df['Sales'] - (df['Sales'] * df['Discount'])
df['Profit Margin (%)'] = round((df['Profit'] / df['Revenue']) * 100, 2)
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month_name()

# 6. Remove negative profits or impossible margins
df = df[df['Profit'] >= 0]
df = df[df['Profit Margin (%)'] <= 100]

# %%
print("\nCleaned Data Summary:")
display(df.describe(include='all'))

print("\nTop 5 cleaned records:")
display(df.head())
# Out:
# Cleaned Data Summary:
#                                     Order_ID                        Date  \
# count                                   5000                        5000
# unique                                  5000                         NaN
# top     ab55273e-b6b5-466a-9324-b8407e872a2a                         NaN
# freq                                       1                         NaN
# mean                                     NaN  2024-10-21 09:25:55.200000
# min                                      NaN         2023-10-25 00:00:00
# 25%                                      NaN         2024-04-15 00:00:00
# 50%                                      NaN         2024-10-23 00:00:00
# 75%                                      NaN         2025-04-27 00:00:00
# max                                      NaN         2025-10-24 00:00:00
# std                                      NaN                         NaN
#
#                Product  Category     Quantity        Sales     Discount  \
# count             5000      5000  5000.000000  5000.000000  5000.000000
# unique            2785         4          NaN          NaN          NaN
# top     Member Clothin  Clothing          NaN          NaN          NaN
# freq                 8      1315          NaN          NaN          NaN
# mean               NaN       NaN     5.510400  2906.795248     0.149644
# min                NaN       NaN     1.000000    50.950000     0.000000
# 25%                NaN       NaN     3.000000  1019.255000     0.070000
# 50%                NaN       NaN     6.000000  2358.160000     0.150000
# 75%                NaN       NaN     8.000000  4273.335000     0.220000
# max                NaN       NaN    10.000000  9990.380000     0.300000
# std                NaN       NaN     2.850459  2242.673441     0.086098
#
#              Profit Region Customer_Segment      Revenue  Profit Margin (%)  \
# count   5000.000000   5000             5000  5000.000000        5000.000000
# unique          NaN      4                3          NaN                NaN
# top             NaN  North         Consumer          NaN                NaN
# freq            NaN   1273             1736          NaN                NaN
# mean     361.480098    NaN              NaN  2469.151505          14.825340
# min        4.130000    NaN              NaN    39.679200           5.160000
# 25%      118.042500    NaN              NaN   867.499850          10.310000
# 50%      271.160000    NaN              NaN  1984.991450          14.670000
# 75%      510.547500    NaN              NaN  3614.586450          18.980000
# max     1949.410000    NaN              NaN  9981.040000          28.500000
# std      319.133913    NaN              NaN  1930.418570           5.306278
#
#                Year     Month
# count   5000.000000      5000
# unique          NaN        12
# top             NaN  December
# freq            NaN       452
# mean    2024.305000       NaN
# min     2023.000000       NaN
# 25%     2024.000000       NaN
# 50%     2024.000000       NaN
# 75%     2025.000000       NaN
# max     2025.000000       NaN
# std        0.645646       NaN
# Top 5 cleaned records:
#                                Order_ID       Date           Product  \
# 0  ab55273e-b6b5-466a-9324-b8407e872a2a 2024-10-25  Among Electronic
# 1  d7b9009f-51da-4065-bb8a-5ef8afcc99f9 2024-12-06   With Electronic
# 2  b77b4d10-e237-4503-996d-b8a7364a4a48 2025-07-14   Should Furnitur
# 3  b6c7e767-53a1-40a2-bb65-c272e31331d1 2025-01-27    Wonder Clothin
# 4  cb9884a3-834c-4ee3-85b2-5517f54cc1ad 2025-04-10       Art Clothin
#
#       Category  Quantity    Sales  Discount  Profit Region Customer_Segment  \
# 0  Electronics         1   754.47      0.07   53.52  North      Home Office
# 1  Electronics        10  4508.26      0.01  373.26  North      Home Office
# 2    Furniture         9  4036.89      0.13  370.30  North         Consumer
# 3     Clothing         6  1883.87      0.06  309.94  North         Consumer
# 4     Clothing         2   782.06      0.10   70.13  North      Home Office
#
#      Revenue  Profit Margin (%)  Year     Month
# 0   701.6571               7.63  2024   October
# 1  4463.1774               8.36  2024  December
# 2  3512.0943              10.54  2025      July
# 3  1770.8378              17.50  2025   January
# 4   703.8540               9.96  2025     April

# %%
CLEAN_PATH = '../data/cleaned_sales_data.csv'
os.makedirs(os.path.dirname(CLEAN_PATH), exist_ok=True)
df.to_csv(CLEAN_PATH, index=False)
print(f"\n✅ Cleaned dataset saved successfully at: {CLEAN_PATH}")
# Out:
# ✅ Cleaned dataset saved successfully at: ../data/cleaned_sales_data.csv
